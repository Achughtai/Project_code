# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
zips = pd.read_csv('uszips.csv')

# %%
zips.head(2)
# Out:
#    zip       lat       lng      city state_id   state_name  zcta  parent_zcta  \
# 0  601  18.18005 -66.75218  Adjuntas       PR  Puerto Rico  True          NaN
# 1  602  18.36074 -67.17519    Aguada       PR  Puerto Rico  True          NaN
#
#    population  density  county_fips county_name  \
# 0     17113.0    102.7        72001    Adjuntas
# 1     37751.0    476.0        72003      Aguada
#
#                         county_weights county_names_all county_fips_all  \
# 0  {"72001": "99.43", "72141": "0.57"}  Adjuntas|Utuado     72001|72141
# 1                     {"72003": "100"}           Aguada           72003
#
#    imprecise  military             timezone
# 0      False     False  America/Puerto_Rico
# 1      False     False  America/Puerto_Rico

# %%
new_zips = zips[['zip', 'population', 'density']]

# %%
new_zips.head(2)
# Out:
#    zip  population  density
# 0  601     17113.0    102.7
# 1  602     37751.0    476.0

# %%
income = pd.read_csv('NYC ZIP CODES_ Population and Household income - Sheet1.csv')

# %%
income.head(2)
# Out:
#   Unnamed: 0  Zip Code               Location                City   \
# 0          1     10577  41.041731, -73.709727   Purchase, New York
# 1          2     10514  41.172330, -73.768948  Chappaqua, New York
#
#   Population  Average household income National Rank
# 0       3,454              $183,686.00             #4
# 1      12,004              $173,368.00             #6

# %%
income.rename(columns= {'Zip Code': 'zip'}, inplace = True)

# %%
income.head(2)
# Out:
#   Unnamed: 0    zip               Location                City  Population   \
# 0          1  10577  41.041731, -73.709727   Purchase, New York       3,454
# 1          2  10514  41.172330, -73.768948  Chappaqua, New York      12,004
#
#   Average household income National Rank
# 0              $183,686.00             #4
# 1              $173,368.00             #6

# %%
income.reset_index(drop=True)
# Out:
#      Unnamed: 0    zip               Location                        City   \
# 0             1  10577  41.041731, -73.709727           Purchase, New York
# 1             2  10514  41.172330, -73.768948          Chappaqua, New York
# 2             3  11568  40.786513, -73.598478       Old Westbury, New York
# 3             4  10503  41.025560, -73.874987  Ardsley On Hudson, New York
# 4             5  10518  41.277016, -73.602519        Cross River, New York
# ...         ...    ...                    ...                          ...
# 1611   1,605.00  10112  40.759167, -73.979668           New York, New York
# 1612   1,607.00  10119  40.750310, -73.992979           New York, New York
# 1613   1,608.00  10152  40.758404, -73.972031           New York, New York
# 1614   1,609.00  10153  40.763622, -73.972439           New York, New York
# 1615   1,610.00  10154  40.757779, -73.972487           New York, New York
#
#      Population  Average household income National Rank
# ...

# %%
new_income= income[['zip','Average household income' ]]

# %%
new_income.head(2)
# Out:
#      zip Average household income
# 0  10577              $183,686.00
# 1  10514              $173,368.00

# %%
census= pd.merge(new_zips, new_income, how='inner',  on = 'zip')

# %%
census.head(2)
# Out:
#      zip  population  density Average household income
# 0   6390       125.0     11.9               $50,521.00
# 1  10001     24117.0  15153.7               $40,932.00

# %%
census.to_csv('project2_census.csv', index=False)

# %%
all_features = pd.read_csv('zillow_house_features.csv')

# %%
all_features.head(3)
# Out:
#        price  bed  bath    sqft  \
# 0  1925000.0  2.0   2.0  1212.0
# 1   489000.0  2.0   1.0     NaN
# 2   330000.0  4.0   2.0  1629.0
#
#                                              address  zip_code    house_type  \
# 0             580 Carroll St #1A, Brooklyn, NY 11215   11215.0         Condo
# 1  70-25 Yellowstone Blvd #20Y, Forest Hills, NY ...   11375.0   Cooperative
# 2             19018 114th Dr, Saint Albans, NY 11412   11412.0  SingleFamily
#
#   year_built     heating  cooling              parking  lot_size  zestimate  \
# 0       2009  Forced air  Central    Garage - Attached   10174.0        NaN
# 1       1965     No Data  Central             0 spaces       NaN        NaN
# 2       1930     No Data  No Data  Garage - Detached,     5057.0   324957.0
#
#    num_photos                                                url
# 0        13.0  https://www.zillow.com/homedetails/580-Carroll...
# 1        20.0  https://www.zillow.com/homedetails/70-25-Yello...
# ...

# %%
all_features= all_features.drop(subset= '' )
